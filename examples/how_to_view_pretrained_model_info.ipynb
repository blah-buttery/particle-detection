# %%
# This file shows you how to view the saved the model information from training

# %%
from PIL import Image
import matplotlib.pyplot as plt

# eventually this model will be deleted, so you might have to train your own first
img = Image.open('../saved_models/ae_1000_1024x1024/metrics.png')
plt.imshow(img)
plt.show()

# %%
import os
import json

model_dir = "../saved_models/ae_1000_1024x1024/"  # Adjusted path
config_path = os.path.join(model_dir, "config.json")

# Check if the config.json file exists
if os.path.exists(config_path):
    with open(config_path, "r") as f:
        config_data = json.load(f)
        print("Model Configuration:")
        for key, value in config_data.items():
            print(f"{key}: {value}")
else:
    print(f"No config.json found in '{model_dir}'")
# Out:
# Model Configuration:
# num_epochs: 1000
# image_size: [1024, 1024]
# batch_size: 8
# learning_rate: 0.001
# ddp: True
# data_dir: ./data
